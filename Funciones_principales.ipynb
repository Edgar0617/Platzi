# %% [markdown]
# <a href="https://colab.research.google.com/github/Edgar0617/Platzi/blob/master/Funciones_principales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
arr = np.random.randint(1,20,10)
arr
# Out:
# array([14, 18,  3, 16, 16, 17,  1, 11,  8,  8])

# %%
matriz = arr.reshape(2,5)
matriz
# Out:
# array([[ 7, 10,  3,  5,  1],
#        [14, 15,  4, 18, 18]])

# %% [markdown]
# ## Traer el número mayor

# %%
arr.max()
# Out:
# 19

# %%
matriz.max()
# Out:
# 19

# %% [markdown]
# ## Indice en el que está el mayor valor

# %%
arr.argmax()
# Out:
# 8

# %%
matriz.argmax()
# Out:
# 8

# %% [markdown]
# ## Traer el número menor

# %%
matriz.min()
# Out:
# 4

# %%
arr.min()
# Out:
# 4

# %% [markdown]
# ## Pico Mas alto y bajo

# %%
arr
# Out:
# array([14, 18,  3, 16, 16, 17,  1, 11,  8,  8])

# %%
matriz
# Out:
# array([[ 7, 10,  3,  5,  1],
#        [14, 15,  4, 18, 18]])

# %%
arr.ptp()
# Out:
# 17

# %%
matriz.ptp(0)
# Out:
# array([ 7,  5,  1, 13, 17])

# %% [markdown]
# ## Percentil

# %%
np.percentile(arr,100)
# Out:
# 18.0

# %% [markdown]
# ## Ordenar los datos de menor a mayor

# %%
arr.sort()
arr
# Out:
# array([ 1,  3,  8,  8, 11, 14, 16, 16, 17, 18])

# %%
np.percentile(arr,50)
# Out:
# 12.5

# %% [markdown]
# ## Mediana

# %%
np.median(arr)
# Out:
# 12.5

# %% [markdown]
# ## Desviación estándar

# %%
np.std(arr)
# Out:
# 5.706137047074842

# %% [markdown]
# ## Varianza

# %%
np.var(arr)
# Out:
# 32.559999999999995

# %% [markdown]
# ## Media

# %%
np.mean(arr)
# Out:
# 11.2

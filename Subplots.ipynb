# %% [markdown]
# <a href="https://colab.research.google.com/github/Edgar0617/Platzi/blob/master/Subplots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,10)
y = np.sin(x)

# %%
fig, axes = plt.subplots()
axes.plot(x,y,'g')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].plot(x,y,'g')
axes[1].plot(y,x,'r')

# %%
fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2)
ax1.plot(x,y,'g')
ax2.plot(y,x,'r')

# %%
fig, axes = plt.subplots(2,4)
axes[0,0].plot(x,np.sin(x))
axes[0,1].plot(x,np.cos(x),'r')
axes[0,2].plot(x,np.tan(x),'y')
axes[0,3].plot(x,np.sin(x)**2)

# %%
fig, ((ax1,ax2,ax3,ax4),(ax5,ax6,ax7,ax8)) = plt.subplots(2,4)
ax1.plot(x,np.sin(x))
ax2.plot(x,np.cos(x),'r')
ax3.plot(x,np.tan(x),'y')
ax4.plot(x,np.sin(x)**2)
ax5.plot(x,np.cos(x),'orange')
ax6.plot(x,np.sin(x))
ax7.plot(x,np.cos(x)*2,'black')
ax8.plot(x,np.sin(x)**3,'r')


fig.tight_layout()

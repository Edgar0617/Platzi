# %% [markdown]
# <a href="https://colab.research.google.com/github/Edgar0617/Platzi/blob/master/Series_Dataframes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
psg_players = pd.Series(['Navas','Mbappe', 'Neymar', 'Messi'],
          index = [1,7,10,30]
          )

# %%
psg_players
# Out:
# 1      Navas
# 7     Mbappe
# 10    Neymar
# 30     Messi
# dtype: object

# %%
dicty = {1:'Navas', 7:'Mbappe', 10:'Neymar', 30:'Messi'}
pd.Series(dicty)
# Out:
# 1      Navas
# 7     Mbappe
# 10    Neymar
# 30     Messi
# dtype: object

# %%
dicty = {'Jugador':['Navas','Mbappe', 'Neymar', 'Messi'],
 'Altura (cm)':[185,178,180,168],
 'Goles':[2,200,300,700]
 }

# %%
dicty
# Out:
# {'Altura (cm)': [185, 178, 180, 168],
#  'Goles': [2, 200, 300, 700],
#  'Jugador': ['Navas', 'Mbappe', 'Neymar', 'Messi']}

# %%
df_players = pd.DataFrame(dicty,index = [1,7,10,30])

# %%
df_players.columns
# Out:
# Index(['Jugador', 'Altura (cm)', 'Goles'], dtype='object')

# %%
df_players.index
# Out:
# Int64Index([1, 7, 10, 30], dtype='int64')

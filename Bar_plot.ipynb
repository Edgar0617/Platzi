# %% [markdown]
# <a href="https://colab.research.google.com/github/Edgar0617/Platzi/blob/master/Bar_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
country = ['Brasil','Japón', 'México', 'Colombia','Alemania']
population = [212000000,126000000, 129000000,51000000,83000000]

# %%
plt.bar(country,population, width = 0.7, color = 'green')
plt.show()

# %%
plt.barh(country,population, color = 'blue')
plt.show()

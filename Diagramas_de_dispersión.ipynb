# %% [markdown]
# <a href="https://colab.research.google.com/github/Edgar0617/Platzi/blob/master/Diagramas_de_dispersi%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Scatterplot

# %%
sns.scatterplot(data=iris, x = 'sepal_length', y='petal_length',hue='species')

# %% [markdown]
# ## Jointplot

# %%
sns.jointplot(data=iris, x='sepal_length', y='petal_length',hue='species')

# %% [markdown]
# ## Relación entre variables

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr(),annot=True,cmap='coolwarm')

# %%
sns.set_theme()
sns.scatterplot(data=iris, x = 'petal_length', y='petal_width',hue='species')

# %%
sns.jointplot(data=iris, x = 'sepal_length', y='petal_width',hue='species')

# %%
sns.scatterplot(data=iris, x = 'sepal_length', y='petal_length',hue='species')

# %% [markdown]
# ## Boxplot

# %%
sns.boxplot(x='species',y='sepal_length',data=iris)

# %% [markdown]
# ## Barplot

# %%
sns.barplot(x='species',y='sepal_length',data=iris)

# %% [markdown]
# <a href="https://colab.research.google.com/github/Edgar0617/Platzi/blob/master/tipos_de_dato_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importar Numpy

# %%
import numpy as np

# %% [markdown]
# Definir una lista

# %%
arr = np.array([1,2,3,4])
arr.dtype
# Out:
# dtype('int64')

# %%
arr = np.array([1,2,3,4], dtype = "int8")
arr.dtype
# Out:
# dtype('int8')

# %%
arr
# Out:
# array([1, 2, 3, 4], dtype=int8)

# %%
hola = np.array(["0","0","3","4"])
hola = hola.astype(np.bool_)
hola
# Out:
# array([False, False,  True,  True])
